# %% [markdown]
# # SF Salinity gradient prelim biogeochemical analysis -- PLOT DEV
# Data pre-processing for comparison to genomic data,
# with correlation heatmaps and scatterplots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
from scipy.stats import norm
from scipy.stats import skew
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Import metadata, requires cleanup

# %%
Sal_metaM = pd.read_csv('SAL_Metadata_MSTRv03.txt', sep='\t')
Sal_metaM.columns

# Sal_metaM.iloc[1:10,1:35]
# Sal_metaM
# Sal_metaM.dtypes
#Sal_metaM.iloc[1:10,1:35]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31f385499044> in <module>()
# ----> 1 Sal_metaM = pd.read_csv('SAL_Metadata_MSTRv03.txt', sep='\t')
#       2 Sal_metaM.columns
#       3
#       4 # Sal_metaM.iloc[1:10,1:35]
#       5 # Sal_metaM
#
# NameError: name 'pd' is not defined

# %%
Sal_metaM.EWcoastGroup.unique()
# Out:
# array(['SF_Ref', 'SF_Rest'], dtype=object)

# %% [markdown]
# ## Metadata massage:
# Makes sense to first add desired features to big dataset, then include in desired order in subsets
#
# ### Calculate new features:

# %%
## SOIL CHEMISTRY

### PHYSICAL ### 
# H2O content 
Sal_metaM['H2O_perc'] = 100-Sal_metaM['Part_DM']  # Water % (g/g)

# Bulk Density
wt_g = Sal_metaM['Core_Weight_oz']*28.3495        # g/oz
core_vol = np.pi*6*16.3871                        # 2 in dia, 6" core = 1*pi*6 cu in * 16.3871 cc/cu. in.
H2O_wt = wt_g*Sal_metaM['H2O_perc']/100
Sal_metaM['Bulk_dens'] = (wt_g - H2O_wt) /core_vol    

# Water filled pore space (%)
Sal_metaM['H2O_FPS'] = H2O_wt/core_vol*100  # this is percent since water weighs 1 g / cc


### GHG cycling ###
# g SOC / m2
Sal_metaM['C_g_m2'] = 15*10000*Sal_metaM['Bulk_dens']*Sal_metaM['Corg_LOI']/100  # cc vol / m2 to 15 cm * BD g/cm3 * %C = g C 

# add N, P
Sal_metaM['N_g_m2'] = 15*10000*Sal_metaM['Bulk_dens']*Sal_metaM['N']/100  # cc vol / m2 to 15 cm * BD g/cm3 * %C = g C 
Sal_metaM['P_g_m2'] = 15*10000*Sal_metaM['Bulk_dens']*Sal_metaM['P']/100  # cc vol / m2 to 15 cm * BD g/cm3 * %C = g C 


# CH4_mg_g_soil_C_m2_d
Sal_metaM['CO2_soilC_mg_g_d'] = Sal_metaM['CO2_mg_m2_h']/Sal_metaM['C_g_m2']*24

# CH4 same way
Sal_metaM['CH4_soilC_ug_g_d'] = Sal_metaM['CH4_ug_m2_h']/Sal_metaM['C_g_m2']*24

# CH4 / CH4% 
Sal_metaM['CH4_CO2'] = Sal_metaM['CH4_ug_m2_h']/Sal_metaM['CO2_mg_m2_h']/10


### Stoichiometry ###
Sal_metaM['CN'] = (Sal_metaM['Corg_LOI']/12.011)  / (Sal_metaM['N']/14.007)  #  ratios accounting for mol. masses
Sal_metaM['CP'] = (Sal_metaM['Corg_LOI']/12.011)  / (Sal_metaM['P']/30.974) 
Sal_metaM['NP'] = (Sal_metaM['N']/14.007)  / (Sal_metaM['P']/30.974) 

Sal_metaM['NP_ext'] = ((Sal_metaM['NO3_N']+ Sal_metaM['NH4_N'])/14.007) / (Sal_metaM['P']/31.007) 
Sal_metaM['NO3_NH4'] = (Sal_metaM['NO3_N'])  / (Sal_metaM['NH4_N'])

# %% [markdown]
# ### Check new features

# %% [raw]
# # BD reality check, make plots
# Site_or = ('Sandmound','WestPond','Mayberry','Browns','RushRanch','Joice','Goodyear','WhiteSlough','Tolay','ChinaCamp','Muzzi')
#
# sns.pairplot(y_vars=['OM_LOI'], x_vars = ['Bulk_dens','H2O_FPS','N','C_g_m2','P'], hue='Location', hue_order=Site_or, data=Sal_metaM)
# sns.pairplot(y_vars=['CO2_soilC_mg_g_d'], x_vars = ['Bulk_dens','CP','N','P','CH4_CO2'], hue='Location', hue_order=Site_or, data=Sal_metaM)
# sns.pairplot(y_vars=['Corg_LOI'], x_vars = ['CN','CP','NP','NP_ext', 'NO3_NH4'], hue='Location', hue_order=Site_or, data=Sal_metaM)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = ['CN','CP','NP','NP_ext', 'NO3_NH4'], hue='Location', hue_order=Site_or, data=Sal_metaM)
# sns.pairplot(y_vars=['OM_LOI'], x_vars = ['C_g_m2','N_g_m2','P_g_m2',], hue='Location', hue_order=Site_or, data=Sal_metaM)
# sns.pairplot(y_vars=['Salinity.y'], x_vars = ['CO2_mg_m2_h','CO2_soilC_mg_g_d','CH4_ug_m2_h','CH4_soilC_ug_g_d'], hue='Location', hue_order=Site_or, data=Sal_metaM)

# %%
### Could make sample subsets here, then feed into below as function
# e.g. only reference sites, then make subsets for each...or not.

# %%
# Define metadata SUBSETS for stats

### Samp_info
samp_dat = ['EWsiteHyd_index','Sample','MG_name','Index', 'Location', 'Pl_Sp', 'EWcoastGroup', 'SALTgroup', 'LU','Depth', 'EW.no','iTag_name.x']
Samp_info = Sal_metaM[samp_dat]
Samp_info['Site_indx'] = Samp_info.index
Samp_info.head(10)

### Soil_Chem 
# dropped: ('Temp','Conductivity', 'CH4_uM_m2_s', 'CH4_uM_m2_s', 'CH4_ppm_s', 'CH4_ppm_s','latitude', 'longitude',  'D1_Read_count', 'iTag_name.x') 
soils_dat = ['Salinity.x', 'Bulk_dens','H2O_FPS','CO2_mg_m2_h','CO2_soilC_mg_g_d', 'CH4_ug_m2_h', 'CH4_CO2', 'CH4_soilC_ug_g_d',
             'pH', 'Cl', 'SO4','Corg_LOI','C','N','P','NO3_N','NH4_N','Olsen_P',
             'CN','CP','NP','NP_ext','NO3_NH4','C_g_m2','N_g_m2','P_g_m2','Fe', 'Mn','Cu','Zn']
Soil_chem = Sal_metaM[soils_dat]



### Pore_water
pw_dat = ['Salinity.y','CO2_mg_m2_h','CH4_ug_m2_h',
          'Cl_pw','SO4_pw','DOC_mg_L', 'NO2_pw', 'NO3_pw', 'NH3_pw','PO4_pw', 
          'Fe_pw', 'Mn_pw', 'Co_pw', 'Cu_pw', 'Zn_pw',
          'Ca_pw', 'Sr_pw', 'Mg_pw', 'Na_pw', 'K_pw',  
          'Al_pw', 'Si_pw','Br_pw', 'F_pw']

Pore_water = Sal_metaM[pw_dat]

# Compile revised dataset, write out
Sal_meta_fix = pd.concat([Samp_info, Soil_chem, Pore_water.iloc[1:,:]], axis=1)
Sal_meta_fix.head()
Sal_meta_fix.columns
Sal_meta_fix.to_csv('SF_sal_meta_FIX3.txt', sep='\t', na_rep='NA')

# %% [markdown]
# ## Prepare log10 data for export

# %%
###### Make LOG 10 data sets for export
Soil_chem = Sal_metaM[soils_dat]
#Soil_chem = Sal_metaM[soils_dat]
Log_Soil_chem = np.log10(Soil_chem)  # log10 SOILS data
Log_Pore_water = np.log10(Pore_water) # log10 Porewater data

## Add back some non-log data 
Log_Soil_chem['CH4_m2_lin'] = Soil_chem['CH4_ug_m2_h']
Log_Soil_chem['CO2_m2_lin'] = Soil_chem['CO2_mg_m2_h']
Log_Soil_chem['Salinity_lin'] = Soil_chem['Salinity.x']

## Drop redund from PW
redund= ['Salinity.y','CO2_mg_m2_h','CH4_ug_m2_h']
Log_Pore_waterDrop = Log_Pore_water.iloc[:,3:]

#Log_Pore_waterDrop
#Log_Soil_chem

# Prep for export
Sal_metaLOG_fix = pd.concat([Samp_info, Log_Soil_chem, Log_Pore_waterDrop.iloc[1:,:]], axis=1)
Sal_metaLOG_fix.head()
Sal_metaLOG_fix.columns
Sal_metaLOG_fix.to_csv('SF_sal_metaLOG_FIX2.txt', sep='\t')


# Soil_chem

# %% [markdown]
# ## Soil Chemistry analysis

# %% [markdown]
# ### Transform data

# %%
# log10 SOILS data
log_Soil_chem = np.log10(Soil_chem)
Log_Soil_chem = pd.concat([Samp_info, log_Soil_chem], axis=1)

# Add back no_log_ Salinity, pH --TODO
Log_Soil_chem['Salin_NL'] = Soil_chem['Salinity.x']

# %% [markdown]
# ### Make heatmap--Soils

# %%
Soil_corr = Log_Soil_chem.corr() #correlation matrix

# Emphasize CH4 related subset
cm=sns.clustermap(Soil_corr.iloc[3:11,:], vmax=1, row_cluster=False, col_cluster=False, square=True);
# cm.cax.set_visible(False) - turns legend off, but doesn't fix whitespace
plt.sca(cm.ax_heatmap) # for tick rotation
plt.yticks(rotation=0)
#cm.savefig("Soil_Chem_CH4corr_SM_heat.pdf")
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5]),
#  <a list of 8 Text yticklabel objects>)

# %% [raw]
# Soil_corr.iloc[3:11,3:12]

# %% [raw]
# Soil_corr.iloc[3:11,12:24]

# %% [raw]
# Soil_corr.iloc[3:11,24:]

# %%
# Clustermap - ALL SOIL vars
cm2=sns.clustermap(Soil_corr.iloc[3:,:], vmax=1, row_cluster=True, col_cluster=True,  square=True);
plt.sca(cm2.ax_heatmap) # More on this in a minute
plt.yticks(rotation=0);

# cm.savefig("Soil_Chem_CH4corr_Big_heat_both_clusts.pdf")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa

# %% [markdown]
# ### Get best vars and scatterplot

# %%
## Get top correlated variables by abs
# Soil_corr = Log_Soil_chem.corr() #correlation matrix

# Get CH4 corr data and abs. values
CH4_corrs =pd.DataFrame(Soil_corr['CH4_ug_m2_h'])
CH4_corrs['AbVal'] = abs(CH4_corrs)  # CH4_corrs.head(10)

# Cutoff at |r| > 0.45, sorted 
CH4_corrs_rF = CH4_corrs[CH4_corrs.AbVal > 0.45]                       # Impose cutoff,  .index gives only cols
CH4_corrs_rF = CH4_corrs_rF.sort_values(by='AbVal', ascending =0)    # make abs col
CH4_corrs_rF
CH4_corrs_rF0 = CH4_corrs_rF.iloc[3:,:]                              # drop autocorrelated, by inspection
CH4_corrs_rF10 = CH4_corrs_rF0.iloc[:,0:9]
CH4_corrs_top10 = CH4_corrs_rF10.sort_values(by='CH4_ug_m2_h', ascending =0)  # sort by orig cor (not abs)  

# Get var list
CH4_top_10 = CH4_corrs_top10.iloc[:,:9].index   # CH4_top_10 # CH4_corrs_top10

# %% [raw]
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[0:5], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[6:11], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[12:14], hue='Location', hue_order=Site_or, data=Log_Soil_chem)

# %% [markdown]
# ### Check data distributions

# %% [raw]
# ### Check distributions are appropriate after log transform
#
# # Soils vs. CH4/m2
# chem = Log_Soil_chem.columns
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[11:16], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[17:22], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[23:28], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[28:33], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[33:38], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = chem[39:42], hue='Location', hue_order=Site_or, data=Log_Soil_chem)

# %% [raw]
# ### Check distributions are appropriate after log transform
#
# ## CO2 vs. ALL soil
# chem = Log_Soil_chem.columns
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[11:16], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[17:22], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[23:28], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[28:33], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[33:39], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = chem[40:42], hue='Location', hue_order=Site_or, data=Log_Soil_chem)

# %% [raw]
# ### Check distributions are appropriate after log transform
#
# # Soils vs. CH4_CO2
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[11:16], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[17:22], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[23:28], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[28:33], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[33:39], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['CH4_CO2'], x_vars = chem[40:42], hue='Location', hue_order=Site_or, data=Log_Soil_chem)

# %%
Log_Soil_chem.columns
# Out:
# Index(['EWsiteHyd_index', 'Sample', 'MG_name', 'Index', 'Location', 'Pl_Sp',
#        'EWcoastGroup', 'SALTgroup', 'LU', 'Depth', 'EW.no', 'iTag_name.x',
#        'Site_indx', 'Salinity.x', 'Bulk_dens', 'H2O_FPS', 'CO2_mg_m2_h',
#        'CO2_soilC_mg_g_d', 'CH4_ug_m2_h', 'CH4_CO2', 'CH4_soilC_ug_g_d', 'pH',
#        'Cl', 'SO4', 'Corg_LOI', 'C', 'N', 'P', 'NO3_N', 'NH4_N', 'Olsen_P',
#        'CN', 'CP', 'NP', 'NP_ext', 'NO3_NH4', 'C_g_m2', 'N_g_m2', 'P_g_m2',
#        'Fe', 'Mn', 'Cu', 'Zn', 'Salin_NL'],
#       dtype='object')

# %% [raw]
# # Plot vs. Salinity
# chem = Log_Soil_chem.columns
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[11:16], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[16:22], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[23:28], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[28:33], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[33:39], hue='Location', hue_order=Site_or, data=Log_Soil_chem)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = chem[40:42], hue='Location', hue_order=Site_or, data=Log_Soil_chem)

# %% [markdown]
# ## Porewater corr

# %% [markdown]
# ### Transform data

# %%
# log10 Porewater data
log_Pore_water = np.log10(Pore_water)
Log_Pore_water = pd.concat([Samp_info, log_Pore_water], axis=1)

# %% [markdown]
# ### Make correlation matrix of soil variables

# %%
Log_PW_corr = Log_Pore_water.corr() #correlation matrix

# Emphasize CH4 related subset
cm=sns.clustermap(Log_PW_corr.iloc[3:12,:], vmax=1, row_cluster=False, col_cluster=False, square=True);
# cm.cax.set_visible(False)
plt.sca(cm.ax_heatmap) # More on this in a minute
plt.yticks(rotation=0)

# cm.savefig("Soil_PoreW_CH4corr_SM_heat.pdf")
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5]),
#  <a list of 9 Text yticklabel objects>)

# %% [raw]
# # Clustermap--All PW vars
# cm2=sns.clustermap(Log_PW_corr.iloc[3:,:], vmax=1, row_cluster=False, col_cluster=False,  square=True);
# plt.sca(cm2.ax_heatmap) # More on this in a minute
# plt.yticks(rotation=0);

# %% [markdown]
# ### Get best vars and scatterplot

# %%
#Log_PW_corr = Log_Pore_water.corr()  #correlation matrix

PW_CH4_corrs =pd.DataFrame(Log_PW_corr['CH4_ug_m2_h'])
PW_CH4_corrs['AbVal'] = abs(PW_CH4_corrs)  # PW_corrs.head(10)
PW_CH4_corrs

# Cutoff at |r| > 0.45, sorted 
PW_corrs_rF = PW_CH4_corrs[PW_CH4_corrs.AbVal > 0.30]                # Impose cutoff,  .index gives only cols
PW_corrs_rF

##
PW_corrs_rF = PW_corrs_rF.sort_values(by='AbVal', ascending =0)    # make abs col
PW_corrs_rF

PW_corrs_rF0 = PW_corrs_rF.iloc[1:,:]                              # drop autocorrelated, by inspection
PW_corrs_rF10 = PW_corrs_rF0.iloc[:,0:9]
PW_corrs_top10 = PW_corrs_rF10.sort_values(by='CH4_ug_m2_h', ascending =0)  # sort by orig cor (not abs)  

# Get var list
PW_CH4_top10 = PW_corrs_top10.iloc[:,:9].index
# PW_CH4_top10 # PW_corrs_top10

# %% [raw]
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = PW_CH4_top10[0:5], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = PW_CH4_top10[6:11], hue='Location', hue_order=Site_or, data=Log_Pore_water)

# %%
### Check distributions appropriate after log transform

# %% [raw]
# ### Check distributions are appropriate after log transform
#
# # Porewater vs. CH4/m2
# pore = Log_Pore_water.columns
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = pore[11:16], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = pore[16:21], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = pore[21:26], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = pore[26:31], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = pore[31:39], hue='Location', hue_order=Site_or, data=Log_Pore_water)

# %% [raw]
# # Porewater vs. CO2/m2
# pore = Log_Pore_water.columns
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = pore[11:16], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = pore[16:21], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = pore[21:26], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = pore[26:31], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['CO2_mg_m2_h'], x_vars = pore[31:39], hue='Location', hue_order=Site_or, data=Log_Pore_water)

# %% [raw]
# # Porewater vs. Salinity
# pore = Log_Pore_water.columns
# sns.pairplot(y_vars=['Salinity.x'], x_vars = pore[11:16], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = pore[16:21], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = pore[21:26], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = pore[26:31], hue='Location', hue_order=Site_or, data=Log_Pore_water)
# sns.pairplot(y_vars=['Salinity.x'], x_vars = pore[31:39], hue='Location', hue_order=Site_or, data=Log_Pore_water)

# %%
## LASSO CV

# %% [markdown]
# ## IMPORT colors tets

# %%
Sal_site_colors = pd.read_csv('Sal_siteColors_test.txt', sep='\t')
Sal_site_colors.columns = ['Location', 'color','Site']
Sal_site_colors
# Out:
#        Location    color         Site
# 0     Sandmound  #3f4c1d    Sandmound
# 1      WestPond  #63703a     WestPond
# 2      Mayberry  #2c9553     Mayberry
# 3        Browns  #275831       Browns
# 4     RushRanch  #3e797c    RushRanch
# 5         Joice  #235355        Joice
# 6      Goodyear  #5f9c9e     Goodyear
# 7   WhiteSlough  #6c92b2  WhiteSlough
# 8         Tolay  #64679d        Tolay
# 9     ChinaCamp  #412142    ChinaCamp
# 10        Muzzi  #8e5589        Muzzi

# %%
Salpal3 = Sal_site_colors['color'].tolist()
Location = Sal_site_colors['Site'].tolist()
#Location
#Salpal3

#Salpal3 = pd.DataFrame(Sal_metaM['Salpal3_col'])
#Salpal3.to_list()

# %%
Site_or = ('Sandmound','WestPond','Mayberry','Browns','RushRanch','Joice','Goodyear','WhiteSlough','Tolay','ChinaCamp','Muzzi')

#sns.pairplot(y_vars=['OM_LOI'], x_vars = ['Bulk_dens','H2O_FPS','N','C_g_m2','P'], hue='Location', hue_order=Site_or, data=Sal_metaM)
sns.pairplot(y_vars=['OM_LOI'], x_vars = ['Bulk_dens','H2O_FPS','N','C_g_m2','P'], hue='Location', palette = Salpal3, hue_order=Site_or, data=Sal_metaM)

# %%
## Plot methane vars like this
sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[0:5], hue='Location',  palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem)
sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[6:11], hue='Location', palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem)

# %%
#kws = dict(s=50, linewidth=.5, edgecolor="w")
# hue_kws=dict(marker=["^", "^", "^", "^", "^", "^", "v", "v", "v", "v", "v"]
#sns.FacetGrid(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[6:11], hue='Location', hue_kws=dict(marker=["^", "^", "^", "^", "^", "^", "v", "v", "v", "v", "v"]), palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem)

# %%
sns.pairplot(y_vars=['CH4_ug_m2_h'], x_vars = CH4_top_10[6:11], hue='Location', palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem)

# %%
sns.lmplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, hue='Location', palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem),#  size=4)
#sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x11fda0f60>,)

# %%
#sns.set_style("white")
#sns.set_style("ticks")

CH4_Sal_plot = sns.lmplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, hue='Location', scatter_kws={'alpha':.8}, palette = Salpal3, hue_order=Site_or, data=Log_Soil_chem)
#scatter_kws={"alpha"=0.5}
CH4_Sal_plot.set_axis_labels('Salinity (PSU)', 'CH4  ug / m2 / h')

# plt.savefig("Test Sal legend a_08.pdf")

# %%
sns.set_style("white")
sns.set_style("ticks")

#fig, (ax1, ax2) = plt.subplots(1,1)
gs = gridspec.GridSpec(1, 1,
                       width_ratios=[1],
                       height_ratios=[1]
                       )
ax1 = plt.subplot(gs[0])

# THE Matplot lib way
_, ax = plt.subplots(figsize=(5,5))
ax.set(xscale='log', yscale='linear')
sns.lmplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, hue='Location', data=Log_Soil_chem,
           scatter_kws={'alpha':0.6}, palette = Salpal3, hue_order=Site_or)
#scatter_kws={"alpha"=0.5}
#CH4_Sal_plot.set_axis_labels('Salinity (PSU)', 'CH4  ug / m2 / h')
ax.grid(True, which="both")
ax.set_title('test')
plt.show()
#plt.savefig("Test legend.pdf")

# %% [markdown]
# ## Change shape by restoration

# %%
# Get subsets by restoration
Log_Soil_chem['LU']
Ref_chem = Log_Soil_chem[Log_Soil_chem.EWcoastGroup == 'SF_Ref']
Rest_chem = Log_Soil_chem[Log_Soil_chem.EWcoastGroup == 'SF_Rest']

# %%
Salpal3
# Out:
# ['#3f4c1d',
#  '#63703a',
#  '#2c9553',
#  '#275831',
#  '#3e797c',
#  '#235355',
#  '#5f9c9e',
#  '#6c92b2',
#  '#64679d',
#  '#412142',
#  '#8e5589']

# %%
# fig, ax = plt.subplots()
plt.figure(figsize=(10,10))
sns.lmplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, hue='Location', data=Ref_chem,
           markers='^', scatter_kws={'alpha':0.6}, palette = Salpal3, hue_order=Site_or)


sns.lmplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, hue='Location', data=Ref_chem,
           markers='o', scatter_kws={'alpha':0.6}, palette = Salpal3, hue_order=Site_or)

plt.title('Attack by Type')
#sns.lmplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, hue='Location', data=Ref_chem,
#           markers='o', scatter_kws={'alpha':0.5}, palette = Salpal3, hue_order=Site_or)
#plt.show()

#scatter_kws={"alpha"=0.5}

# %% [raw]
# fig, ax = plt.subplots()
#
# ax.scatter(x[cluster==1],y[cluster==1], marker='^')
# ax.scatter(x[cluster==2],y[cluster==2], marker='s')
#
# plt.show()
# # ax.scatter(x[cluster==2],y[cluster==2], marker='s')

# %% [markdown]
# # Fix busted overlays with regplot-- can use on gridspec
# lmplot wont take ax commands

# %%
# Note regplot wants a complete list of colors-- but can use this to advantage to recode shapes...
# Requires DF merge though...
#Log_Soil_chem # o = Log_Soil_chem.Index.sort_values()
colors= Sal_site_colors[['Location','color']]
# colors

# %%
# Merge with site colors
Log_Soil_chem_colors = pd.merge(Sal_site_colors, Log_Soil_chem, on='Location')      # Log_Soil_chem_colors
pointcolors = Log_Soil_chem_colors['color']                                         # get point colors

# %%
# To get color mapped need 'facecolors' = in scatter_kws
# Why are they out of order tho?
sns.set_style("white")
sns.set_style("ticks")

sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, data=Log_Soil_chem_colors, #_shape, #hue='Location',
      scatter_kws={'facecolors':pointcolors,'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
sns.despine()

# %%
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='v', data=Log_Soil_chem_colors, #_shape, #hue='Location',
      scatter_kws={'facecolors':pointcolors,'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
sns.despine()

# %% [raw]
# sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='v', data=Log_Soil_chem_colors, #_shape, #hue='Location',
#      edgecolor= pointcolors, facecolors="none")#, alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),

# %%
Ref_chem = Log_Soil_chem_colors[Log_Soil_chem_colors.EWcoastGroup == 'SF_Ref']
Rest_chem = Log_Soil_chem_colors[Log_Soil_chem_colors.EWcoastGroup == 'SF_Rest']
#pointcolors # = Log_Soil_chem_colors['color'] 


#Plotting colors thrown off by NA values, here for example drop CH4 data NAs
Ref_chem.dropna(subset = ['CH4_ug_m2_h'], inplace=True)
#Ref_chem['CH4_ug_m2_h']
#Ref_chem
#Ref_chem['CH4_ug_m2_h']
# Rest_chem

# %%
# Combine each with different marker styles.
# Note color palette is recalc'd for each plot

sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='o', data=Ref_chem, #_shape, #hue='Location',
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
    
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='^', data=Rest_chem, #_shape, #hue='Location',
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
sns.despine()

# %%
# Here use log Axis!!!
_, ax = plt.subplots(figsize=(4,4))
ax.set(xscale='log', yscale='linear')
#ax.grid(True, which="both")
ax.set_xticklabels(['5','10','1','10'], rotation=90)  # needs work 

sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='o', data=Ref_chem, #_shape, #hue='Location',
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
    
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='^', data=Rest_chem, #_shape, #hue='Location',
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
#ax.set_axis_labels('Salinity (PSU)', 'CH4  ug / m2 / h')

plt.xlabel('Salinity (PSU)')
plt.ylabel('CH4  (ug / m2 /h)')
sns.despine()


#fig = plt.figure()         - not working yet
#fig.savefig('test.pdf')    - not working yet

# %%
# Gridspec plot compositing 

# Import PdfPages
from matplotlib.backends.backend_pdf import PdfPages
# pp = PdfPages('soil_CH4_Sal_corr_test.pdf')                # Initialize the pdf file  # uncomment to save

# Make GRID
fig = plt.figure(figsize=(7.5, 2.5))            # Define plot
gs = gridspec.GridSpec(1, 3)                    # Declare grid dimension   
gs.update(left=0, right=1, wspace=0.45)        # Fine tune panel spacing

ax1 = plt.subplot(gs[0, 0])                     # 1st axis
ax2 = plt.subplot(gs[0, 1])                     # 2nd axis 
ax3 = plt.subplot(gs[0, 2])                     # 3rd axis 

# Add axis parameters
ax2.set(xscale='log', yscale='linear')                  # log ax2
ax3.set(xscale='log', yscale='linear')                  # log ax2
ax2.set_xticklabels(['5','10','1','10'], rotation=90)   # needs work 
#ax1.xaxis.set_ticks_position('top')

# Reverse X axes
ax1.invert_xaxis()
ax2.invert_xaxis()
ax3.invert_xaxis()

# Truncate data ?
ax1.set_ylim(-1, 3.5)
ax2.set_ylim(-1, 3.5)
ax3.set_ylim(0, 1.7)

# Plot 1: log CH4 vs. Salinity (by shape)
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='o', data=Ref_chem, ax=ax1, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})  
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='^', data=Rest_chem, ax=ax1, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Plot 2: log CH4 vs. Log Sal
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='o', data=Ref_chem, ax=ax2, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})     
sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, marker ='^', data=Rest_chem, ax=ax2, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Plot 3: log C vs. Log Sal
sns.regplot(y='C', x = 'Salin_NL', fit_reg=False, marker ='o', data=Ref_chem, ax=ax3, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})     
sns.regplot(y='C', x = 'Salin_NL', fit_reg=False, marker ='^', data=Rest_chem, ax=ax3, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})
    
    
    
#ax.set_axis_labels('Salinity (PSU)', 'CH4  ug / m2 / h')

# fig.xlabel('Salinity (PSU)')
# plt.ylabel('CH4  (ug / m2 /h)')

sns.despine()

#ax = plt.gca()

#ax1.invert_xaxis()
#plt.tight_layout()
gs.tight_layout(fig)
plt.show()

# Save the figure to the file
#pp.savefig()                              # uncomment to save

# Close the file
#pp.close()                                # uncomment to save

#subplots_adjust()

# %%
# Import PdfPages
from matplotlib.backends.backend_pdf import PdfPages
# pp = PdfPages('soil_C_Sal_corr_test.pdf')                # Initialize the pdf file  # uncomment to save


# Make GRID
fig = plt.figure(figsize=(7.5, 2.5))            # Define plot
gs = gridspec.GridSpec(1, 3)                # Declare grid dimension   
gs.update(left=0, right=1, wspace=0.45)     # Fine tune panel spacing

ax1 = plt.subplot(gs[0, 0])                 # Create first axis
ax2 = plt.subplot(gs[0, 1])                 # Create second axis 
ax3 = plt.subplot(gs[0, 2])
#ax2.set_xlim(0.1, 1.8)
ax3.set_ylim(0.5, 2.5)

# Add axis parameters
#ax2.set(xscale='log', yscale='linear')
#ax3.set(xscale='log', yscale='linear')
# ax2.set_xticklabels(['5','10','1','10'], rotation=90)  # needs work 
#ax1.xaxis.set_ticks_position('top')


# Plot 1: log CH4 vs. Salinity (by shape)
sns.regplot(y='NP', x = 'C', fit_reg=False, marker ='o', data=Ref_chem, ax=ax1, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})  
sns.regplot(y='NP', x = 'C', fit_reg=False, marker ='^', data=Rest_chem, ax=ax1, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Plot 2: log CH4 vs. Log Sal
sns.regplot(y='Bulk_dens', x = 'C', fit_reg=False, order=2, truncate=False, marker ='o', data=Ref_chem, ax=ax2, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5, 's':50})  
sns.regplot(y='Bulk_dens', x = 'C', fit_reg=False, order=2, marker ='^', data=Rest_chem, ax=ax2, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Plot 3: log C vs. Log Sal
sns.regplot(y='NH4_N', x = 'C' , fit_reg=False, marker ='o', data=Ref_chem, ax=ax3, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})     
sns.regplot(y='NH4_N', x = 'C', fit_reg=False, marker ='^', data=Rest_chem, ax=ax3, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Plot 3b: log C vs. Log Sal
#sns.regplot(y='NH4_N', x = 'Salinity.x' , fit_reg=False, marker ='o', data=Ref_chem, ax=ax3, 
#      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})     
#sns.regplot(y='NH4_N', x = 'Salinity.x', fit_reg=False, marker ='^', data=Rest_chem, ax=ax3, 
#      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})


# Wrap plot params and export
sns.despine()                               # Drop upper and right bounding boxes
gs.tight_layout(fig)                        # Make tight layout

# pp.savefig()                              # uncomment to save      
# pp.close()                                # Close the file   # uncomment to save

# %% [markdown]
# # Scatterplot function for Rest_Ref shapes

# %%
# Plots two scatters (Rest, Ref) on same axis, using color vectors per point
def Rest_ref_scatter(y,x,axis):
    sns.regplot(y=y, x = x, fit_reg=False, marker ='o', data=Ref_chem, ax=axis, 
      scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.5})  
    sns.regplot(y=y, x = x, fit_reg=False, marker ='^', data=Rest_chem, ax=axis, 
      scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.5})
    sns.despine()

# %%
## Test function - single plot
_, ax = plt.subplots(figsize=(4,4))                # Simplest annotation for testing, matplotlib not Gridspec 
Rest_ref_scatter('CH4_ug_m2_h','Salin_NL',ax)

# %% [markdown]
# ## Test in Gridspec  - YASSSSS

# %%
# Import PdfPages
from matplotlib.backends.backend_pdf import PdfPages
# pp = PdfPages('soil_CH4_Sal_corr_fxn_test.pdf')                # Initialize the pdf file  # uncomment to save

# Make 1x3 GRID
fig = plt.figure(figsize=(7.5, 2.5))        # Define plot
gs = gridspec.GridSpec(1, 3)                # Declare grid dimension   
gs.update(left=0, right=1, wspace=0.45)     # Fine tune panel spacing

ax1 = plt.subplot(gs[0, 0])                 # 1st axis
ax2 = plt.subplot(gs[0, 1])                 # 2nd axis
ax3 = plt.subplot(gs[0, 2])                 # 3rd axis

#ax1.invert_xaxis()
#ax2.invert_xaxis()
ax3.invert_xaxis()

ax2.set(xscale='log', yscale='linear')
ax3.set(xscale='log', yscale='linear')

Rest_ref_scatter('CH4_ug_m2_h','Salin_NL',ax1)
Rest_ref_scatter('CH4_ug_m2_h','Salin_NL',ax2)
Rest_ref_scatter('C','Salin_NL',ax3)

gs.tight_layout(fig)                     # Make tight layout
#pp.savefig()                            # Save the figure PDF created at top, else add file name .pdf  or #plt.show() #('soil_CH4_Sal_corr_test.pdf')
#pp.close()                              # Close the file

# %%
# pp = PdfPages('soil_CH4_Sal_corr_fxn_test2.pdf')                # Initialize the pdf file

# Make 1x3 GRID
fig = plt.figure(figsize=(7.5, 2.5))        # Define plot
gs = gridspec.GridSpec(1, 3)                # Declare grid dimension   
#gs.update(left=0, right=1, wspace=0.45)     # Fine tune panel spacing

ax1 = plt.subplot(gs[0, 0])                 # 1st axis
ax2 = plt.subplot(gs[0, 1])                 # 2nd axis
ax3 = plt.subplot(gs[0, 2])                 # 3rd axis

#ax1.invert_xaxis()
ax2.invert_xaxis()
#ax3.invert_xaxis()
ax3.set_xlim(-0.6, 1.5)

#ax1.set(xscale='log', yscale='linear')
#ax3.set(xscale='log', yscale='linear')

Rest_ref_scatter('CH4_ug_m2_h','Salin_NL',ax1)
Rest_ref_scatter('CO2_mg_m2_h','Salin_NL',ax2)
Rest_ref_scatter('CH4_ug_m2_h','CO2_mg_m2_h',ax3)

gs.tight_layout(fig)                    # Make tight layout
# pp.savefig()                            # Save the figure PDF created at top, else add file name .pdf  or #plt.show() #('soil_CH4_Sal_corr_test.pdf')
# pp.close()   # Close the file

# %%
# more plotting function candy

# %% [raw]
# n = 5
# axn = pd.Series(range(0,n))
# axnL = axn.tolist()
# axnL
# for i in AxnL:
#     ax= 'ax'+ (i) '=plt.subplot(gs[0,' + (i)'])'
#     print ax

# %% [markdown]
# # TODO:
# ### Get Linear data, merge with colors, redo all with LOG transf.
# ### PDF outputs
# ### Matrix plotting matplot lib or Gridspec
#
# ### Scatterplot function,

# %% [markdown]
# ## Get Linear data, merge with colors, redo all with LOG transf.

# %%
Sal_meta_fix
Sal_meta_fix.columns[1:20]
#Soil_chem2 = Sal_meta_fix['Sample', 'MG_name', 'Index', 'Location', 'Pl_Sp', 'EWcoastGroup',
#       'SALTgroup', 'LU', 'Depth', 'EW.no', 'iTag_name.x', 'Site_indx',
#       'Salinity.x', 'Bulk_dens', 'H2O_FPS', 'CO2_mg_m2_h', 'CO2_soilC_mg_g_d']
#       'CH4_ug_m2_h', 'CH4_CO2', 'CH4_soilC_ug_g_d', 'pH', 'Cl', 'SO4']#,
#       'Corg_LOI', 'C', 'N', 'P', 'NO3_N', 'NH4_N', 'Olsen_P', 'CN', 'CP',
#       'NP', 'NP_ext', 'NO3_NH4', 'C_g_m2', 'N_g_m2', 'P_g_m2', 'Fe', 'Mn'] #,'Cu', 'Zn'

Sal_meta_fix2 = Sal_meta_fix.iloc[:,1:20]
Sal_meta_fix2['CH4_ug_m2_h'] = Sal_meta_fix2['CH4_ug_m2_h'].clip(lower=0.001)


#Sal_meta_fix2['CH4_ug_m2_h'] = Sal_meta_fix2['CH4_ug_m2_h'].where( = < 0,other=0.1)
#Soil_chem
#Pore_water
#Chem_data=Soil_chem.join(Pore_water, rsuffix='pw')

# %%
#Chem_data
# Merge with site colors
Soil_chem_colors = pd.merge(Sal_site_colors, Sal_meta_fix2, on='Location', how='right')      # Log_Soil_chem_colors
#pointcolors = Log_Soil_chem_colors['color']                                         # get point colors

# %%
Ref_chem2 = Soil_chem_colors[Soil_chem_colors.EWcoastGroup == 'SF_Ref']
Rest_chem2 = Soil_chem_colors[Soil_chem_colors.EWcoastGroup == 'SF_Rest']
#pointcolors # = Log_Soil_chem_colors['color'] 
# Ref_chem2

# %%
# Here use log Axis!!!
_, ax = plt.subplots(figsize=(4,4))
ax.set(xscale='linear', yscale='log')
#ax.grid(True, which="both")
#ax.set_xticklabels(['5','10','1','10'], rotation=90)  # needs work 

sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='o', data=Ref_chem2, #_shape, #hue='Location',
      scatter_kws={'facecolors':Ref_chem2['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),
    
sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='^', data=Rest_chem2, #_shape, #hue='Location',
    scatter_kws={'facecolors':Rest_chem2['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
    #markers='x'),
#ax.set_axis_labels('Salinity (PSU)', 'CH4  ug / m2 / h')

plt.xlabel('Salinity (PSU)')
plt.ylabel('CH4  (ug / m2 /h)')
sns.despine()

# %% [markdown]
# ### Plot Poffenbarger 2011 data, then with SF data

# %%
from matplotlib import ticker

# %%
# Import poff data
CH4poff = pd.read_csv('Poffen_CH4_data.txt', sep='\t')
# CH4poff.head()

# %%
# Plot data
_, ax = plt.subplots(figsize=(4,4))
ax.set(xscale='linear', yscale='log')               # Here use log Axis!!! 
    
sns.regplot(y='CH4g_m2y', x = 'Salinity_ppt', fit_reg=False, marker ='o', data=CH4poff, 
            color="grey", scatter_kws={'alpha':0.5})

plt.xlabel('Salinity (PSU)')
plt.ylabel('CH4  (g / m2 /y)')
sns.despine()

# %% [markdown]
# ### plot on two axes

# %%
# plot on two axes 
fig, ax1 = plt.subplots(figsize=(4,4))
ax1.set(xscale='linear', yscale='log')               # Here use log Axis!!! 
ax2.set(xscale='linear', yscale='log')
ax2 = ax1.twinx()
#ax3 = ax1.twinx()

ax1 = sns.regplot(y='CH4g_m2y', x = 'Salinity_ppt', fit_reg=False, marker ='.', data=CH4poff, 
            color="black", scatter_kws={'alpha':0.7})


ax2 = sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='^', data=Rest_chem2, #_shape, #hue='Location',
    scatter_kws={'facecolors':Rest_chem2['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)

sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='o', data=Ref_chem2, #_shape, #hue='Location',
      scatter_kws={'facecolors':Ref_chem2['color'],'alpha':0.5})#, palette = Salpal3, hue_order=Site_or)
      #markers='x'),


    
    
ax1.yaxis.tick_left()
plt.ylabel('CH4  (g / m2 / y)')

ax2.yaxis.tick_right()
ax1.set(xscale='linear', yscale='log')

plt.xlabel('Salinity (PSU)')
plt.ylabel('CH4  (g / m2 / y)')

# ax1.pf
sns.despine(top=True, right=False)

# %% [markdown]
# # Plot SF CH4 vs. Poffenbarger

# %%
from matplotlib import ticker

# %%
#Soil_chem_colors['SF_CH4m2y'] = (Soil_chem_colors['CH4_ug_m2_h']*(10**(1.12))*.34)
Soil_chem_colors['SF_CH4m2y'] = (Soil_chem_colors['CH4_ug_m2_h']*.34)
Soil_chem_colors['SF_CH4m2y'].max()
# Out:
# 571.16714920000004

# %%
##############################################
# plot on two axes -- using ax2 = ax1.twinx()
##############################################

#pp = PdfPages('CH4_v_Sal_SF_v_Poff.pdf')                                 # Initialize the pdf file
#pp = PdfPages('CH4_v_Sal_SF_NO_Poff.pdf')                               # Initialize the pdf file

fig, ax1 = plt.subplots(figsize=(5,4))

#######################
# First axis, SF CH4
#######################
#ax1 = 
sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='^', data=Rest_chem2,   # SF_Restored
    scatter_kws={'facecolors':Rest_chem2['color'],'alpha':0.5})

sns.regplot(y='CH4_ug_m2_h', x = 'Salinity.x', fit_reg=False, marker ='o', data=Ref_chem2,          # SF_Reference
      scatter_kws={'facecolors':Ref_chem2['color'],'alpha':0.5})

#sns.regplot(y='SF_CH4m2y', x = 'Salinity.x', fit_reg=False, marker ='x', data=Soil_chem_colors,       # Poff_2011
#            color="black", scatter_kws={'alpha':0.1})

# Axis 1 params 
ax1.set(xscale='linear', yscale='log')                                   # log axis 
ax1.set_ylim(bottom = 0.3, top=3000)                                     # range needed for two axes
#ax1.set_ylabel('CH4  (ug / m2 / h)')                                    # y_label, needs to be after ax2 info...

# relabel ticks -- requires: from matplotlib import ticker
ax1.get_yaxis().set_major_formatter(                                     # not scientific label
    ticker.FuncFormatter(lambda x, p: format(int(x), ',')))              # integer format 
plt.yticks([1, 10, 100,1000])                                            # label array


#######################
# 2nd axis, Poff 2011 metanalysis
#######################
ax2 = ax1.twinx()                                                        ### plot 2nd y-axis, copy x-axis ###

ax2 = sns.regplot(y='CH4g_m2y', x = 'Salinity_ppt', fit_reg=False, marker ='.', data=CH4poff,         # Poff_2011
            color="orange", scatter_kws={'alpha':0.7})

# dummy for aligning, data converted by poff method...hidden by alpha = 0
sns.regplot(y='SF_CH4m2y', x = 'Salinity.x', fit_reg=False, marker ='x', data=Soil_chem_colors,       # SF / y
            color="black", scatter_kws={'alpha':0})

# axis 2 parameters
ax2.set(xscale='linear', yscale='log')                                   # log y-axis
ax2.set_ylabel('CH4  (g / m2 / y)')                                      # y-axis label
ax2.set_ylim(bottom = 0.3, top=700)       # bottom = 0.35 if ax1 = 0.01  # range needed for two axes

# relabel ticks -- requires: from matplotlib import ticker
ax2.get_yaxis().set_major_formatter(                                     # not scientific label     
    ticker.FuncFormatter(lambda x, p: format(int(x), ',')))              # integer format 
plt.yticks([0.1,1,10, 100,500])                                          # label array


###### Clean up ######
ax1.set_ylabel('CH4  (ug / m2 / h)')                                     # y1 label (needs to be at end)
ax1.set_xlabel('Salinity (ppt)')                                         # X-label
sns.despine(top=True, right=False)                                       # remove top box 
fig.tight_layout()                                                       # Make tight layout

# Save the figure PDF created at top 
#pp.savefig()                             
#pp.close()   # Close the file

# %% [raw]
# sns.regplot(y='C', x = 'Salinity.x', fit_reg=False, marker ='^', data=Rest_chem, #_shape, #hue='Location',
#       scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.6})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),
#
# sns.regplot(y='C', x = 'Salinity.x', fit_reg=False, marker ='o', data=Ref_chem, #_shape, #hue='Location',
#       scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.6})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),
# sns.despine()

# %% [raw]
# sns.regplot(y='NP', x = 'C', fit_reg=False, marker ='^', data=Rest_chem, #_shape, #hue='Location',
#       scatter_kws={'facecolors':Rest_chem['color'],'alpha':0.6})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),
#
# sns.regplot(y='NP', x = 'C', fit_reg=False, marker ='o', data=Ref_chem, #_shape, #hue='Location',
#       scatter_kws={'facecolors':Ref_chem['color'],'alpha':0.6})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),
# sns.despine()

# %% [raw]
# ### Shapes to scatter_kws FAILs

# %% [raw]
# # get points shapes for ref and merge
# rest = ['SF_Ref','SF_Rest']
# shape = ['x','o']
# Rest_shape = pd.DataFrame(shape,rest)
#
# Rest_shape.columns = ['shape']
# Rest_shape['EWcoastGroup'] = ['SF_Ref','SF_Rest'] #Rest_shape.index.values()
# Rest_shape

# %% [raw]
# # Merge shapes with colored data
# Log_Soil_chem_colors_shape = pd.merge(Rest_shape, Log_Soil_chem_colors, on = 'EWcoastGroup', how='right')
# Log_Soil_chem_colors_shape
#
# # re-get point colors
# pointcolors = Log_Soil_chem_colors_shape['color']
# # markerS = Log_Soil_chem_colors_shape['shape']

# %% [raw]
# sns.regplot(y='CH4_ug_m2_h', x = 'Salin_NL', fit_reg=False, data=Log_Soil_chem_colors_shape, #hue='Location',
#       scatter_kws={'facecolors':pointcolors,'alpha':0.5, 'marker':markerS})#, palette = Salpal3, hue_order=Site_or)
#       #markers='x'),

# %% [raw]
# DF_0['color'] =  ["#91FF61"]*25 + ["#BA61FF"]*25 + ["#91FF61"]*25 + ["#BA61FF"]*25
# DF_0
