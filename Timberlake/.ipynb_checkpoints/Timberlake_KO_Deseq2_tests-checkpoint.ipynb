# %% [markdown]
# # DESeq2 testing of Timberlake KOs via phyloseq, Dev
# 2nd major draft, here normalize all genes, deprioritize FC and volcano plots.  Incorporates more of DESeq2 vignette along with Phyloseq tutorial materials. Here dropping source soil data entirely.

# %%
library(phyloseq)
library(ggplot2)
library(RColorBrewer)
library(stringr)

suppressMessages(library(vegan))
suppressMessages(library(DESeq2))
suppressMessages(library(gplots))

# %% [markdown]
# ## Import and pre-process files

# %%
## KO table import, filter samples                           
TL_KO_raw0 <- read.csv("Timberlake_MG_KO_data.csv", header=TRUE)     # Raw KO table w. Fxn as taxon)        #, row.names=1)
keep_samps <- names(TL_KO_raw0[1:19])                                # Get colnames for Incubated Samples   # keep_samps
TL_KO_raw <- TL_KO_raw0[, colnames(TL_KO_raw0) %in% keep_samps]      # Filter DF columns to keep            
TL_KO_raw$Fxn <- TL_KO_raw0$Fxn                                      # Replace Fxn column (last)            #names(TL_KO_raw)

# df of KO gene fxns
TL_KO_fxn <-data.frame(fxn = TL_KO_raw0$Fxn)                         # Get Fxn df 
row.names(TL_KO_fxn)<-TL_KO_raw0$KO                                  # KO as rowname                                        # head(TL_KO_raw)  # head(TL_KO_fxn)

# KO fxns as Phyloseq object
suppressWarnings(KOTaxTable<-tax_table(TL_KO_fxn))                   # Fxn as PHYLOSEQ tax table 
colnames(KOTaxTable) <- colnames(TL_KO_fxn)                          # Add back colnames
row.names(KOTaxTable) <- row.names(TL_KO_fxn)                        # Add back rownames                                    # KOTaxTable

# %%
# Gene Ontology and fxn Colors import
BGC_ont <- read.csv("Ontology_KO_CNPSch4_Fm_whh.csv", header=TRUE)   # Ontology
BGC_colors <- read.csv("Ontol_KO_L2_Color_KEY_whh.csv")              # Colors                       # head(BGC_ont)  # head(BGC_colors) # dim(BGC_ont)
BGC_ont_col <- merge(BGC_ont, BGC_colors, by = "L2", all.x =TRUE)    # Merge ont & colors           # BGC_ont_col # BGC_colors

# Drop FERMENTATION (?) for clarity
BGC_ont_col <-BGC_ont_col[order(BGC_ont_col$Index.x),]               # Sort (readability only)
BGC_ont_col <- subset(BGC_ont_col, L2 != "Fermentation")             # Drop ferment  # BGC_ont_col

# %%
# Only CNPSch4 genes from Ontology
bgc_KOu <- unique(data.frame(KO=BGC_ont$KO))                         # only KOs from BGC_ont
TL_bgc_KO <- merge(bgc_KOu, TL_KO_raw)                               # Merge with TL KO                     #dim(bgc_KO) # head(bgc_KO) # dim(TL_bgc_KO) #head(TL_bgc_KO) # TL_bgc_KO

# %%
# Sample Mapping import
map_both <-read.table("Timberlake_sample_map_both.txt", sep="\t", header=TRUE)            # head(map_both) # dim(map_both) # 50 x 11  - note iTag dropouts
map_MG <-map_both[!(is.na(map_both$MG_name)),]                                            # drop NA in MG samps   
map_MG <- map_MG[order(map_MG$itag_meta_order2),]                                         # sort by index (itag intentional)
map_MG_only <- data.frame(Sample=map_MG$MG_name, Treat=map_MG$Treat, Depth=map_MG$Depth)  # keep only relevant cols 
# map_MG # map_MG_only

### Finalize Sample MAP for Deseq
row.names(map_MG_only) <- map_MG_only$Sample                         # Sample as row names
map_MG_PhyloDESeq <- map_MG_only[,2:3]                               # Drop sample col
map = map_MG_PhyloDESeq[1:18,]                                       # Drop SAMPLES HERE, incubations only       #rownames(map)

# %% [markdown]
# ## Phyloseq to DESeq2

# %%
# Prep KO count data for OTU table 
KOin <- data.frame(unique(TL_KO_raw))                                # DF for KOin, unique used to drop redund.
row.names(KOin)<-KOin$KO                                             # Make rownames KO numbers
No_fxn <- as.matrix(KOin[,3:ncol(KOin)-1])                           # Drop KO, fxn, why does it makes me drop first two cols, not one?
                                                                     # KOin # No_fxn
# make PHYLOSEQ KO ->"OTU Table"
class(No_fxn)<-"numeric"                                             # Make numeric for phyloseq
KO_otu <-otu_table(No_fxn, taxa_are_rows=TRUE, errorIfNULL = TRUE)   # Make OTU table phyloseq object    #head(OTU_ko) # OTU_ko # KOin #head(KO_otu)

# %%
# Make Phyloseq sample data
Map<-sample_data(map)          # map

# %%
### Make combined Phyloseq OBJECT
physeq = phyloseq(KO_otu, Map, KOTaxTable)
# INSPECT: # physeq

# %%
# Assign CONTROL treatment 
# phyloseq patch before DESeq
sample_data(physeq)$Treat <- relevel(as.factor(get_variable(physeq, "Treat")), ref="Control")

# %%
# EXPORT phyloseq TO deseq
KO_phy2des <- phyloseq_to_deseq2(physeq, ~ Treat)
# INSPECT: # KO_phy2des
# Out:
# converting counts to integer mode

# %% [markdown]
# ## DESeq2 for Diff abund

# %%
# Wald test
KO_phy2des <- DESeq(KO_phy2des, test="Wald", fitType="parametric") # Test
# Out:
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing

# %%
# INSPECT DESeq fmt data set, includes estimated dispersions
# KO_phy2des

# %%
# Overall results  -- why nothing sig when contrasts are?
# res <- results(KO_phy2des)
# resultsNames(KO_phy2des)
# summary(res)

# %%
# options(repr.plot.width=4, repr.plot.height=4)
# plotMA(res) #, ylim=c(-2,2))

# %%
# Likelihood ratio test, "ANOVA - like" for mulitple factors 
# -- note here some are sig again, unlike above Wald test
lrt <- DESeq(KO_phy2des, test="LRT", reduced=~1)
res_LRT <- results(lrt)
res_LRT
# Out:
# using pre-existing size factors
# estimating dispersions
# found already estimated dispersions, replacing these
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# log2 fold change (MLE): Treat SO4 vs Control
# LRT p-value: '~ Treat' vs '~ 1'
# DataFrame with 19163 rows and 6 columns
#          baseMean log2FoldChange     lfcSE      stat       pvalue        padj
#         <numeric>      <numeric> <numeric> <numeric>    <numeric>   <numeric>
# K00001 2196.01739   -0.002290359 0.1256439 11.731121 0.0083633446 0.040522031
# K00002   39.28156   -0.278464385 0.4556102  2.264430 0.5193694450 0.692632434
# K00003 1708.08914   -0.043393867 0.1281779  2.553929 0.4656237408 0.649689242
# K00004  249.30229    0.192720668 0.2241525 18.403634 0.0003630898 0.004507227
# K00005   16.98076    0.106901625 0.5550605  2.390483 0.4954087417 0.673409979
# ...           ...            ...       ...       ...          ...         ...
# K19788   4.268293      0.4762256 0.9771854  2.722626    0.4363959   0.6245784
# K19789   2.812504      2.0958966 1.6436880  1.571395    0.6658931   0.8086719
# K19790   0.000000             NA        NA        NA           NA          NA
# K19791  73.962771     -0.4075100 0.4504732  5.155330    0.1607701   0.3222233
# K19792   0.000000             NA        NA        NA           NA          NA

# %%
options(repr.plot.width=4, repr.plot.height=4)
plotMA(res_LRT) #, ylim=c(-2,2))
# Out:
# Plot with title “”

# %% [markdown]
# ## DESeq2 Linear contrasts

# %% [markdown]
# ### Function for linear contrasts with p > filter, FC cutoff

# %%
# Function for linear contrasts, results cutoff and merge with Ontology
DSq_cntrstF = function(Treat_col, Treat1, Treat2) {                      # Treat_col: column with treatment data
    alpha = 0.05                                                         # Treat1: for increase compared with Ref
    FC = 1                                                               # Treat2: Ref for comparison  

    T1_T2_De <- results(KO_phy2des,contrast = c(Treat_col, Treat1, Treat2),independentFiltering = FALSE) # DESeq2 results
    T1_T2_DeS <- T1_T2_De[which(T1_T2_De$padj < alpha), ]                # filter by alpha 
    T1_T2_DeSQ <-data.frame(T1_T2_DeS)                                   # make df 
    T1_T2_DeSQ$KO <-row.names(T1_T2_DeSQ)                                # add KO as rownames

    # Merge with CNP ontology, filter FC > 1 
    T1_T2_DeSQ <- merge(T1_T2_DeSQ, BGC_ont_col, by ='KO')               # merge w Ontology
    T1_T2_DeSQ_FC1 <- T1_T2_DeSQ[abs(T1_T2_DeSQ$log2FoldChange) > FC,]   # filter FC > 1 
    return(T1_T2_DeSQ_FC1)
}

# %%
# Test contrasts fxn: 
ASW_Ctrl_DeSQ_FC <- DSq_cntrstF("Treat", "ASW", "Control")                # ASW_Ctrl_DeSQ_FC

# %%
# Create ALL Contrasts results sets
ASW_Ctrl_FC <- DSq_cntrstF("Treat", "ASW", "Control")
ASW0S_Ctrl_FC <- DSq_cntrstF("Treat", "ASW_noS", "Control")
SO4_Ctrl_FC <- DSq_cntrstF("Treat", "SO4", "Control")
ASW_SO4_FC <- DSq_cntrstF("Treat", "ASW", "SO4")
ASW_ASW0S_FC <- DSq_cntrstF("Treat","ASW", "ASW_noS")
ASW0S_SO4_FC <- DSq_cntrstF("Treat","ASW_noS","SO4")                       #ASW0S_SO4_FC

# %%
ASW_Ctrl_DeSQ_FC
# Out:
#    KO     baseMean    log2FoldChange lfcSE     stat      pvalue
# 1  K00192   38.761347  4.479912      0.7401863  6.052411 1.426936e-09
# 2  K00193   50.665353  4.470773      0.8172873  5.470259 4.493790e-08
# 4  K00205   43.725791  2.510745      0.8923535  2.813621 4.898687e-03
# 5  K00264    5.814251 -4.879384      1.3251209 -3.682218 2.312137e-04
# 9  K00394  272.373858 -1.526048      0.3342448 -4.565660 4.979251e-06
# 10 K00395  112.733140 -1.541936      0.3494865 -4.412005 1.024176e-05
# 12 K00531    3.644158  5.861989      2.0877951  2.807742 4.989025e-03
# 13 K00581   31.889518  2.822478      0.9658854  2.922167 3.476050e-03
# 14 K00582    8.495023  7.134514      1.8216882  3.916430 8.986998e-05
# 18 K00917  183.705096  1.518381      0.3921300  3.872137 1.078851e-04
# 20 K01182  192.255868  1.567379      0.3804848  4.119426 3.798172e-05
# 25 K01624  911.316501  1.047597      0.2734517  3.831013 1.276167e-04
# 27 K01804  576.162356  1.146973      0.2833380  4.048074 5.164079e-05
# 28 K01805  750.858708  1.029295      0.2517644  4.088327 4.344948e-05
# 29 K02636 1109.100930 -1.069090      0.3611441 -2.960287 3.073527e-03
# 30 K04099   91.472666  1.286923      0.4342269  2.963711 3.039535e-03
# 31 K04480  129.720817  1.309886      0.4162199  3.147101 1.648979e-03
# 32 K05823   12.498341  3.921575      0.9874120  3.971569 7.140080e-05
# 33 K07175  567.754531  1.487233      0.3677856  4.043749 5.260322e-05
# 34 K07768  405.998725  1.632183      0.4596719  3.550756 3.841269e-04
# 35 K07776  463.358698  1.368216      0.3528797  3.877288 1.056273e-04
# 37 K10676  731.441958  1.658292      0.5130426  3.232269 1.228113e-03
# 38 K10944   31.763373 -1.988729      0.6502468 -3.058422 2.225064e-03
# 39 K10944   31.763373 -1.988729      0.6502468 -3.058422 2.225064e-03
# 40 K10945   28.446272 -2.580875      0.7291247 -3.539690 4.005980e-04
# 41 K10945   28.446272 -2.580875      0.7291247 -3.539690 4.005980e-04
# 42 K10946   27.070166 -2.436549      0.5972886 -4.079349 4.516192e-05
# 43 K10946   27.070166 -2.436549      0.5972886 -4.079349 4.516192e-05
# 44 K11081   10.146258 -1.766032      0.6101469 -2.894437 3.798395e-03
# 45 K11180  114.527005 -2.128184      0.4985370 -4.268858 1.964763e-05
# 46 K11181  104.342640 -1.979579      0.4597919 -4.305381 1.666989e-05
# 47 K11260   16.970569  8.071731      1.5638795  5.161351 2.451741e-07
# 48 K13788  219.396764  1.634241      0.4886703  3.344261 8.250204e-04
# 49 K14084  138.781146 -1.898228      0.5010812 -3.788264 1.517036e-04
# 50 K15062   77.722422  1.785672      0.5957992  2.997103 2.725588e-03
# 51 K15986   84.348212  1.410020      0.4967727  2.838360 4.534607e-03
# 52 K16157   39.300958  1.806105      0.5544814  3.257288 1.124824e-03
# 54 K17818   15.005731  2.518536      0.8847091  2.846739 4.416959e-03
#    padj         L2               Index.x L1           L3            L4
# 1  7.064375e-06 H2_production    344     Fermentation H2_prod       NA
# 2  5.540032e-05 CH4_acetate      309     CH4_cycling  CH4_acetat    NA
# 4  4.551070e-02 CH4_H2_reduction 297     CH4_cycling  CH4_H2.red    NA
# 5  7.555282e-03 NH4_assimilation 205     Nitrogen     NH4_asim      NA
# 9  8.806697e-04 SO4_D.reduction  269     Sulfur       SO4_D.red     NA
# 10 1.352200e-03 SO4_D.reduction  270     Sulfur       SO4_D.red     NA
# 12 4.612142e-02 N2_fixation      217     Nitrogen     N2_fix        NA
# 13 3.624526e-02 CH4_Archaeal     326     CH4_cycling  CH4_Archa     NA
# 14 4.578485e-03 CH4_Archaeal     327     CH4_cycling  CH4_Archa     NA
# 18 5.031418e-03 Sugars            14     Carbon       C_sug_lact    NA
# 20 2.991938e-03 Polymers          52     Carbon       C_poly_starch NA
# 25 5.487520e-03 Sugars            11     Carbon       C_sug_sucr    NA
# 27 3.428087e-03 Sugars            41     Carbon       C_sug_arab    NA
# 28 3.128115e-03 Polymers          62     Carbon       C_poly_xylos  NA
# 29 3.361872e-02 H2_production    352     Fermentation H2_prod       NA
# 30 3.343124e-02 Aromatic         144     Carbon       C_arom_PAH    NA
# 31 2.290666e-02 CH4_methylotroph 313     CH4_cycling  CH4_methanol  NA
# 32 4.056431e-03 Aromatic         136     Carbon       C_arom_BTEX   NA
# 33 3.448270e-03 P_regulation     231     Phosphorus   P_regulat     NA
# 34 9.849628e-03 P_regulation     228     Phosphorus   P_regulat     NA
# 35 5.026144e-03 P_regulation     229     Phosphorus   P_regulat     NA
# 37 1.912348e-02 Aromatic         134     Carbon       C_arom_nitro  NA
# 38 2.751682e-02 NH3_oxidation    192     Nitrogen     NH3_oxid      NA
# 39 2.751682e-02 CH4_oxidation    283     CH4_cycling  CH4_ox        NA
# 40 1.008057e-02 CH4_oxidation    284     CH4_cycling  CH4_ox        NA
# 41 1.008057e-02 NH3_oxidation    193     Nitrogen     NH3_oxid      NA
# 42 3.142324e-03 NH3_oxidation    194     Nitrogen     NH3_oxid      NA
# 43 3.142324e-03 CH4_oxidation    285     CH4_cycling  CH4_ox        NA
# 44 3.866032e-02 Phn_transport    246     Phosphorus   P_Phn         NA
# 45 1.918509e-03 SO4_D.reduction  271     Sulfur       SO4_D.red     NA
# 46 1.755770e-03 SO4_D.reduction  272     Sulfur       SO4_D.red     NA
# 47 1.532175e-04 CH4_H2_reduction 298     CH4_cycling  CH4_H2.red    NA
# 48 1.518710e-02 CH4_acetate      307     CH4_cycling  CH4_acetat    NA
# 49 6.076261e-03 CH4_methylotroph 320     CH4_cycling  CH4_methylam  NA
# 50 3.143276e-02 Polymers          85     Carbon       C_poly_lignin NA
# 51 4.368696e-02 PolyP-ases       235     Phosphorus   P_PyroP       NA
# 52 1.823518e-02 CH4_oxidation    286     CH4_cycling  CH4_ox        NA
# 54 4.317474e-02 Sugars            45     Carbon       C_sug_arab    NA
#    gene
# 1  cdhA
# 2  cdhC
# 4  fwdF, fmdF
# 5  GLT1
# 9  aprA
# 10 aprB
# 12 anfG
# 13 mtrE
# 14 mtrF
# 18 lacC
# 20 E3.2.1.10
# 25 FBA, fbaA
# 27 araA
# 28 xylA
# 29 petC
# 30 desB, galA
# 31 mtaB
# 32 E3.5.1.47
# 33 phoH2
# 34 senX3
# 35 regX3
# 37 tfdB
# 38 pmoA-amoA
# 39 pmoA-amoA
# 40 pmoB-amoB
# 41 pmoB-amoB
# 42 pmoC-amoC
# 43 pmoC-amoC
# 44 phnS
# 45 dsrA
# 46 dsrB
# 47 fwdG
# 48 pta
# 49 mttC
# 50 ligY
# 51 ppaC
# 52 mmoX
# 54 ARD1
#    fxn
# 1  acetyl-CoA decarbonylase/synthase complex subunit alpha
# 2  acetyl-CoA decarbonylase/synthase complex subunit beta
# 4  4Fe-4S ferredoxin
# 5  glutamate synthase (NADPH/NADH)
# 9  adenylylsulfate reductase, subunit A
# 10 adenylylsulfate reductase, subunit B
# 12 nitrogenase delta subunit
# 13 tetrahydromethanopterin S-methyltransferase subunit E
# 14 tetrahydromethanopterin S-methyltransferase subunit F
# 18 tagatose 6-phosphate kinase
# 20 oligo-1,6-glucosidase
# 25 fructose-bisphosphate aldolase, class II
# 27 L-arabinose isomerase
# 28 xylose isomerase
# 29 cytochrome b6-f complex iron-sulfur subunit
# 30 gallate dioxygenase
# 31 methanol---5-hydroxybenzimidazolylcobamide Co-methyltransferase
# 32 N-acetyldiaminopimelate deacetylase
# 33 PhoH-like ATPase
# 34 two-component system, OmpR family, sensor histidine kinase SenX3
# 35 two-component system, OmpR family, response regulator RegX3
# 37 2,4-dichlorophenol 6-monooxygenase
# 38 methane/ammonia monooxygenase subunit A
# 39 methane/ammonia monooxygenase subunit A
# 40 methane/ammonia monooxygenase subunit B
# 41 methane/ammonia monooxygenase subunit B
# 42 methane/ammonia monooxygenase subunit C
# 43 methane/ammonia monooxygenase subunit C
# 44 2-aminoethylphosphonate transport system substrate-binding protein
# 45 sulfite reductase alpha subunit
# 46 sulfite reductase beta subunit
# 47 4Fe-4S ferredoxin
# 48 phosphate acetyltransferase
# 49 trimethylamine corrinoid protein
# 50 OH-DDVA meta-cleavage compound hydrolase
# 51 manganese-dependent inorganic pyrophosphatase
# 52 methane monooxygenase component A alpha chain
# 54 D-arabinitol dehydrogenase (NADP+)
#    EC                        sm_name
# 1  [EC:1.2.7.4]              K00192 H2_prod cdhA
# 2  [EC:2.3.1.-]              K00193 CH4_acetat cdhC
# 4                            K00205 CH4_H2.red fwdF
# 5  [EC:1.4.1.13 1.4.1.14]    K00264 NH4_asim GLT1
# 9  [EC:1.8.99.2]             K00394 SO4_D.red aprA
# 10 [EC:1.8.99.2]             K00395 SO4_D.red aprB
# 12 [EC:1.18.6.1]             K00531 N2_fix anfG
# 13 [EC:2.1.1.86]             K00581 CH4_Archa mtrE
# 14 [EC:2.1.1.86]             K00582 CH4_Archa mtrF
# 18 [EC:2.7.1.144]            K00917 C_sug_lact lacC
# 20 [EC:3.2.1.10]             K01182 C_poly_starch E3.2
# 25 [EC:4.1.2.13]             K01624 C_sug_sucr FBA,
# 27 [EC:5.3.1.4]              K01804 C_sug_arab araA
# 28 [EC:5.3.1.5]              K01805 C_poly_xylos xylA
# 29 [EC:1.10.9.1]             K02636 H2_prod petC
# 30 [EC:1.13.11.57]           K04099 C_arom_PAH desB
# 31 [EC:2.1.1.90]             K04480 CH4_methanol mtaB
# 32 [EC:3.5.1.47]             K05823 C_arom_BTEX E3.5
# 33                           K07175 P_regulat phoH
# 34 [EC:2.7.13.3]             K07768 P_regulat senX
# 35                           K07776 P_regulat regX
# 37 [EC:1.14.13.20]           K10676 C_arom_nitro tfdB
# 38 [EC:1.14.18.3 1.14.99.39] K10944 NH3_oxid pmoA
# 39 [EC:1.14.18.3 1.14.99.39] K10944 CH4_ox pmoA
# 40                           K10945 CH4_ox pmoB
# 41                           K10945 NH3_oxid pmoB
# 42                           K10946 NH3_oxid pmoC
# 43                           K10946 CH4_ox pmoC
# 44                           K11081 P_Phn phnS
# 45 [EC:1.8.99.3 1.8.99.5]    K11180 SO4_D.red dsrA
# 46 [EC:1.8.99.3 1.8.99.5]    K11181 SO4_D.red dsrB
# 47                           K11260 CH4_H2.red fwdG
# 48 [EC:2.3.1.8]              K13788 CH4_acetat pta
# 49                           K14084 CH4_methylam mttC
# 50                           K15062 C_poly_lignin ligY
# 51                           K15986 P_PyroP ppaC
# 52 [EC:1.14.13.25]           K16157 CH4_ox mmoX
# 54 [EC:1.1.1.287]            K17818 C_sug_arab ARD1
#    mid_name                                         Index.y color
# 1  K00192 H2_prod ( cdhA ) acetyl-CoA decarbo       25      #fe9829
# 2  K00193 CH4_acetat ( cdhC ) acetyl-CoA decarbo    20      #7e7e7e
# 4  K00205 CH4_H2.red ( fwdF ) 4Fe-4S ferredoxin     19      #b0b0b0
# 5  K00264 NH4_asim ( GLT1 ) glutamate synthase       7      #356542
# 9  K00394 SO4_D.red ( aprA ) adenylylsulfate re     16      #ce248f
# 10 K00395 SO4_D.red ( aprB ) adenylylsulfate re     16      #ce248f
# 12 K00531 N2_fix ( anfG ) nitrogenase delta          8      #344338
# 13 K00581 CH4_Archa ( mtrE ) tetrahydromethanop     22      #181818
# 14 K00582 CH4_Archa ( mtrF ) tetrahydromethanop     22      #181818
# 18 K00917 C_sug_lact ( lacC ) tagatose 6-phospha     0      #e94c3e
# 20 K01182 C_poly_starch ( E3.2 ) oligo-1,6-glucosid  1      #b8302a
# 25 K01624 C_sug_sucr ( FBA, ) fructose-bisphosph     0      #e94c3e
# 27 K01804 C_sug_arab ( araA ) L-arabinose isomer     0      #e94c3e
# 28 K01805 C_poly_xylos ( xylA ) xylose isomerase     1      #b8302a
# 29 K02636 H2_prod ( petC ) cytochrome b6-f co       25      #fe9829
# 30 K04099 C_arom_PAH ( desB ) gallate dioxygenas     2      #5f3230
# 31 K04480 CH4_methanol ( mtaB ) methanol---5-hydro  21      #515151
# 32 K05823 C_arom_BTEX ( E3.5 ) N-acetyldiaminopim    2      #5f3230
# 33 K07175 P_regulat ( phoH ) PhoH-like ATPase       10      #3787c0
# 34 K07768 P_regulat ( senX ) two-component syst     10      #3787c0
# 35 K07776 P_regulat ( regX ) two-component syst     10      #3787c0
# 37 K10676 C_arom_nitro ( tfdB ) 2,4-dichlorophenol   2      #5f3230
# 38 K10944 NH3_oxid ( pmoA ) methane/ammonia mo       5      #41a359
# 39 K10944 CH4_ox ( pmoA ) methane/ammonia mo        18      #d9d9d9
# 40 K10945 CH4_ox ( pmoB ) methane/ammonia mo        18      #d9d9d9
# 41 K10945 NH3_oxid ( pmoB ) methane/ammonia mo       5      #41a359
# 42 K10946 NH3_oxid ( pmoC ) methane/ammonia mo       5      #41a359
# 43 K10946 CH4_ox ( pmoC ) methane/ammonia mo        18      #d9d9d9
# 44 K11081 P_Phn ( phnS ) 2-aminoethylphosph         13      #35556c
# 45 K11180 SO4_D.red ( dsrA ) sulfite reductase      16      #ce248f
# 46 K11181 SO4_D.red ( dsrB ) sulfite reductase      16      #ce248f
# 47 K11260 CH4_H2.red ( fwdG ) 4Fe-4S ferredoxin     19      #b0b0b0
# 48 K13788 CH4_acetat ( pta ) phosphate acetyltr     20      #7e7e7e
# 49 K14084 CH4_methylam ( mttC ) trimethylamine cor  21      #515151
# 50 K15062 C_poly_lignin ( ligY ) OH-DDVA meta-cleav  1      #b8302a
# 51 K15986 P_PyroP ( ppaC ) manganese-dependen       11      #3676a4
# 52 K16157 CH4_ox ( mmoX ) methane monooxygen        18      #d9d9d9
# 54 K17818 C_sug_arab ( ARD1 ) D-arabinitol dehyd     0      #e94c3e

# %%
SO4_Ctrl_FC
# Out:
#      KO baseMean log2FoldChange lfcSE stat pvalue padj L2 Index.x L1 L3 L4 gene
#      fxn EC sm_name mid_name Index.y color

# %% [markdown]
# ### Collect significnant KOs, all treats

# %%
# gather KO lists
ASW_Ctrl_KO <- data.frame(KO=ASW_Ctrl_FC$KO)
ASW0S_Ctrl_KO <- data.frame(KO=ASW0S_Ctrl_FC$KO)
SO4_Ctrl_KO <- data.frame(KO=SO4_Ctrl_FC$KO)
ASW_SO4_KO <- data.frame(KO=ASW_SO4_FC$KO)
ASW_ASW0S_KO <- data.frame(KO=ASW_ASW0S_FC$KO)
ASW0S_SO4_KO <- data.frame(KO=ASW0S_SO4_FC$KO)

# Combine lists, make unique
Resp_KO <- (rbind(ASW_Ctrl_KO, ASW0S_Ctrl_KO, SO4_Ctrl_KO, ASW_SO4_KO, ASW_ASW0S_KO, ASW0S_SO4_KO))
Resp_KOu <- unique(Resp_KO)                                               # Resp_KO #length(Resp_KO)   # dim(Resp_KO) # dim(Resp_KOu)
row.names(Resp_KOu) <-Resp_KOu$KO                                         # Resp_KOu

# %% [markdown]
# ## Get DESeq2 variance stablized data and Counts

# %%
# From updated phyloseq to Deseq2 tutorial at https://github/Joey711/phyloseq/issues/283
# Adding size factors and dispersion estimates before variance stabilization, as instructed

KO_phy2des_vs <- estimateSizeFactors(KO_phy2des)
KO_phy2des_vs <- estimateDispersions(KO_phy2des)
KO_phy2des_VST <- getVarianceStabilizedData(KO_phy2des)
# KO_phy2des_VST

KO_table_VST <- data.frame(KO_phy2des_VST)    # shorten name
KO_table_VST$KO <- row.names(KO_table_VST)    # index rows
# Out:
# found already estimated dispersions, replacing these
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates

# %%
# CHECK VST df 
#head(KO_table_VST)

# %%
## REPLACE VST data with COUNTS
KO_vs_counts <- counts(KO_phy2des_vs, normalized=TRUE)     # get counts                       #head(KO_vs_counts) 
KO_table_VST <- data.frame(KO_vs_counts)                   # make df, shorten name
# KO_table_VST$KO <- row.names(KO_vs_counts)                 # index rows                       # 
# head(KO_table_VST)
# colSums(KO_table_VST[,1:ncol(KO_table_VST)-1])

# %%
# Scale OTU VST table counts to CPM (Counts per million)
sampTots<-colSums(KO_table_VST)                          # Get sample totals   #[,1:ncol(OTU_table_VST)-1]) 
KO_VST_CPM<-sweep(KO_table_VST*1000000,2,sampTots,'/')   # Sweep matrix by:[div. by samp total * 1e+06]    
KO_VST_CPM$KO <- row.names(KO_VST_CPM)                   # Add KO as column for later merges    # head(KO_VST_CPM) # colSums(KO_VST_CPM) # KO_VST_CPM

# %% [markdown]
# # Prep heatmap - Count data w only responsive KOs

# %%
# get KO Counts from DE KOs by MERGE
KO_table_VST_resp <- merge(Resp_KOu, KO_VST_CPM, by="KO")     # merge                #dim(KO_table_VST_resp0)  # dim(Resp_KOu)
KO_table_VST_respM <- KO_table_VST_resp[,-1]                     # Drop KO
row.names(KO_table_VST_respM)<-KO_table_VST_resp$KO              # add KO as ind     # KO_table_VST_respM 
KO_table_VST_respM[KO_table_VST_respM==0] <-0.5                  # Replace 0 values with psuedo counts for LOG transf.  #KO_table_VST_respM # KO_table_VST_respM

# Get z-score data, here of log10
KO_table_VST_respZ <- data.frame(t(scale(t(log10(KO_table_VST_respM)), center=TRUE, scale=TRUE)))     # z-scores, log10 
KO_table_VST_respZ$KO <-row.names(KO_table_VST_respZ)                                                 # KO as rowname  #KO_table_VST_respZ

# %% [markdown]
# ### Add Ontology hier / colors

# %%
## Add in ONTOLOGY              # BGC_colors # BGC_ont
# Merge colors with Ontology
BGC_ont_colors <- merge(BGC_colors[,-1], BGC_ont, by="L2", all.x = TRUE)       # merge
BGC_ont_colors <- BGC_ont_colors[order(BGC_ont_colors$KO),]                    # Sort by KO       #BGC_ont$Index

# Merge Ontology with Responsive KO z-scores
KO_table_VSTrespZc <- merge(BGC_ont_colors, KO_table_VST_respZ, by='KO')       # merge
KO_table_VSTrespZc <- KO_table_VSTrespZc[order(KO_table_VSTrespZc$Index),]     # sort by index    # head(KO_table_VSTrespZc) # dim(KO_table_VSTrespZc) # attributes(KO_table_VSTrespZc[1,]) # KO_table_VSTrespZc[80:120,]

# get only data, add names to rows
KO_Resp_HeatDS0 <-KO_table_VSTrespZc                    # rename
KO_Resp_HeatDS <-KO_Resp_HeatDS0[,13:30]                # data only
KO_Resp_HeatDSt<-t(KO_Resp_HeatDS)                      # transpose (non-unique rows)
colnames(KO_Resp_HeatDSt) <- KO_Resp_HeatDS0$sm_name    # add sm names for FXN 
KO_Resp_HeatDStt <-t(KO_Resp_HeatDSt)                   # retranspose, keeps non-unique rownames 
# KO_Resp_HeatDStt

# get colors for heat
L2_colors <- as.character(KO_Resp_HeatDS0$color)

# %%
# Make heatmap -- ALL vertical
#trt_colors <- c('green', 'green','green','green','green','blue','blue','blue','blue','blue','purple','purple','purple','purple','purple','red','red','red')
trt_colors <- c('#cccccc','#cccccc','#cccccc','#cccccc','#cccccc', '#fabe58', '#fabe58','#fabe58','#fabe58','#fabe58','#6bb96d','#6bb96d','#6bb96d','#6bb96d','#6bb96d', '#9ac5e0','#9ac5e0','#9ac5e0')
# trt_colors <- c('#7ec377','#7ec377','#7ec377','#7ec377','#7ec377','#9ac5e0','#9ac5e0','#9ac5e0','#9ac5e0','#9ac5e0','#7e75b6','#7e75b6','#7e75b6','#7e75b6','#7e75b6','#f88f74','#f88f74','#f88f74')

options(repr.plot.width=5, repr.plot.height=8)
heatmap.2(KO_Resp_HeatDStt, Rowv=F, Colv=F, ColSideColors=trt_colors, RowSideColors = L2_colors,trace="none", key=TRUE, density.info="none",scale="column", margins = c(10, 10), col = rev(brewer.pal(11,"RdYlBu")))

## HORIZONTAL PLOT
# options(repr.plot.width=8, repr.plot.height=4)
# heatmap.2(KO_Resp_HeatDSt[,1:60], Rowv=F, Colv=F, trace="none", key=TRUE, ColSideColors = L2_colors[1:60], density.info="none",scale="column", margins = c(8, 6), col = rev(brewer.pal(11,"RdYlBu")))
# Out:
# Warning message in heatmap.2(KO_Resp_HeatDStt, Rowv = F, Colv = F, ColSideColors = trt_colors, :
# “Discrepancy: Rowv is FALSE, while dendrogram is `both'. Omitting row dendogram.”Warning message in heatmap.2(KO_Resp_HeatDStt, Rowv = F, Colv = F, ColSideColors = trt_colors, :
# “Discrepancy: Colv is FALSE, while dendrogram is `column'. Omitting column dendogram.”
# Plot with title “Color Key”

# %% [markdown]
# ## NMDS PLOTS

# %% [markdown]
# ### Define plotting function

# %%
biom_plot_cats_nmds <- function(biom, group, env){
  biomT<-t(biom)    # Transpose so cols are vars
  
  # Test ADONIS models, extract params
  bT_adonis <- adonis(biomT  ~ group, permutations=99, method="bray");
  R2 <- round(bT_adonis$aov.tab$R2[1], digits=3)
  P <- bT_adonis$aov.tab$"Pr(>F)"[1]
  
  # NMDS
  bT_mds<-suppressMessages(metaMDS(biomT[,-1], distance="bray",k=3, trymax=10));                  # run NMDS
  bT_mds_DF = data.frame(MDS1=bT_mds$points[,1], MDS2=bT_mds$points[,2], group)  # Make data frame
  stress=round(bT_mds$stress, digits = 3)                                      # get NMDS stress
  
  # Plot NMDS by assembly group
  pA <- ggplot(bT_mds_DF,aes(x=MDS1, y=MDS2, color=group))+geom_point()+stat_ellipse(level=0.95);
  pB <-pA + annotate("text", x = (0.9*(max(bT_mds_DF$MDS1))), y = max(bT_mds_DF$MDS2), label = paste("italic(R) ^ 2 ==", R2),
                     parse = TRUE);
  pC <-pB + annotate("text", x = (0.7*(min(bT_mds_DF$MDS1))), y = min(bT_mds_DF$MDS2), label = paste("italic(Stress):", stress),
                     parse = TRUE);
  pD <- pC + theme(legend.title=element_blank())
  
  return(pD)
}

# %% [markdown]
# ###  New Adaptation

# %%
## ALL GENES

# Get counts per sample,  from # KO_VST_CPM  not  KO_table_VST
KO_table_VST_nk <- KO_VST_CPM[, 1:(ncol(KO_VST_CPM)-1)]  # Drop KO column, previously needed for merge  # KO_table_VST_nk
#KO_table_VST_nk <- KO_table_VST[, 1:(ncol(KO_table_VST)-1)]  # Drop KO column, previously needed for merge  # KO_table_VST_nk

# Get treatment vector
Treat <-map_MG_only$Treat[1:ncol(KO_table_VST_nk)]      # Treat

## PLOT
options(repr.plot.width=5, repr.plot.height=3)
#suppressWarnings(biom_plot_cats_nmds(KO_table_VST_nk, Treat))
suppressMessages(biom_plot_cats_nmds(KO_table_VST_nk, Treat))
# Out:
# Square root transformation
# Wisconsin double standardization
# Run 0 stress 0.04853686
# Run 1 stress 0.04854501
# ... Procrustes: rmse 0.001585622  max resid 0.003965297
# ... Similar to previous best
# Run 2 stress 0.0485409
# ... Procrustes: rmse 0.002027156  max resid 0.004671491
# ... Similar to previous best
# Run 3 stress 0.04854073
# ... Procrustes: rmse 0.0009543088  max resid 0.002432316
# ... Similar to previous best
# Run 4 stress 0.04854123
# ... Procrustes: rmse 0.001055064  max resid 0.002755231
# ... Similar to previous best
# Run 5 stress 0.04854122
# ... Procrustes: rmse 0.0009628458  max resid 0.002469989
# ... Similar to previous best
# Run 6 stress 0.04853966
# ... Procrustes: rmse 0.0007913018  max resid 0.002082736
# ... Similar to previous best
# Run 7 stress 0.04854045
# ... Procrustes: rmse 0.0009139564  max resid 0.002365854
# ... Similar to previous best
# Run 8 stress 0.04853921
# ... Procrustes: rmse 0.0007008177  max resid 0.001853705
# ... Similar to previous best
# Run 9 stress 0.04853856
# ... Procrustes: rmse 0.0005289037  max resid 0.001425887
# ... Similar to previous best
# Run 10 stress 0.04853941
# ... Procrustes: rmse 0.000733115  max resid 0.001896575
# ... Similar to previous best
# Run 11 stress 0.04875861
# ... Procrustes: rmse 0.007596035  max resid 0.01926027
# Run 12 stress 0.04853735
# ... Procrustes: rmse 0.0002146839  max resid 0.0006110605
# ... Similar to previous best
# Run 13 stress 0.04853976
# ... Procrustes: rmse 0.0007982279  max resid 0.002034764
# ... Similar to previous best
# Run 14 stress 0.04853761
# ... Procrustes: rmse 0.0003069879  max resid 0.0008561168
# ... Similar to previous best
# Run 15 stress 0.04853982
# ... Procrustes: rmse 0.001838636  max resid 0.00422556
# ... Similar to previous best
# Run 16 stress 0.05176856
# Run 17 stress 0.04854942
# ... Procrustes: rmse 0.002060634  max resid 0.005127506
# ... Similar to previous best
# Run 18 stress 0.04854245
# ... Procrustes: rmse 0.001136019  max resid 0.002876699
# ... Similar to previous best
# Run 19 stress 0.04853919
# ... Procrustes: rmse 0.001727423  max resid 0.003979751
# ... Similar to previous best
# Run 20 stress 0.05100338
# *** Solution reached
# Too few points to calculate an ellipse
# plot without title

# %%
# MANY attempts to supress STD OUT coming from metaMDS
# bT_mds<-metaMDS(t(KO_table_VST_nk), distance="bray",k=3, trymax=10); #  run NMDS 
# bT_mds<-suppressMessages(metaMDS(t(KO_table_VST_nk), distance="bray",k=3, trymax=10))                  # run NMDS
# bT_mds<-suppressWarnings(metaMDS(t(KO_table_VST_nk), distance="bray",k=3, trymax=10))
#{r, echo=FALSE,results='hide',fig.keep='all'}
# bT_mds<-invisible(metaMDS(t(KO_table_VST_nk), distance="bray",k=3, trymax=10))   
# bT_mds<-invisible(metaMDS(t(KO_table_VST_nk), distance="bray",k=3, trymax=10))

# %% [markdown]
# ## Fold change and volcano plots:
# ## Define Functions

# %%
# Plot fold change by organism, ontology colors
fold_plot = function(sigtab){

    # L2 order
    x = tapply(sigtab$log2FoldChange, sigtab$L2, function(x) max(x))
    x = sort(x, TRUE)
    sigtab$L2 <- factor(as.character(sigtab$L2), levels = names(x))
    # sm_name order
    x = tapply(sigtab$log2FoldChange, sigtab$sm_name, function(x) max(x))
    x = sort(x, TRUE)
    sigtab$sm_name <- factor(as.character(sigtab$sm_name), levels = names(x))
    
    sigtab <- sigtab[order(sigtab$Index.y),]                                           # Sort Table by factor ordering index
    sigtab$L2 <- factor(sigtab$L2, levels = unique(sigtab$L2[order(sigtab$Index.y)]))  # Reorder factor levels

    # Get factor colors as vector
    colmat <-unique(data.frame(L2=sigtab$L2, color=sigtab$color))
    w = c(unlist(as.character(colmat$color)))
    
        
    #pt_size = (sigtab$baseMean/100)
    p <- ggplot(sigtab, aes(x=sm_name, y=log2FoldChange, color=L2)) + geom_point(size = 2) +
        theme(axis.text.x = element_text(angle = 90)) +
        scale_color_manual(values=w) 
    p + geom_point(aes(size = baseMean))
    }

# %%
# Volcano FC plot, colored by ontology
volc_plot = function(sigtab){
    sigtab <- sigtab[order(sigtab$Index.y),]                                           # Sort Table by factor ordering index
    sigtab$L2 <- factor(sigtab$L2, levels = unique(sigtab$L2[order(sigtab$Index.y)]))  # Reorder factor levels

    # Get factor colors as vector
    colmat <-unique(data.frame(L2=sigtab$L2, color=sigtab$color))
    w = c(unlist(as.character(colmat$color)))
    
    # PLOT
    ggplot(sigtab, aes(x=log2FoldChange, y=baseMean, group=L2, color=L2)) + geom_point(size=2) + 
    scale_color_manual(values=w)
}

# %%
#TEST fold_plot FUNCTION
options(repr.plot.width=9, repr.plot.height=7)
fold_plot(ASW_Ctrl_DeSQ_FC) # [1:50,])
# fold_plot(ASW_Ctrl_DeSeQ) # [1:50,])
# Out:
# plot without title

# %%
# TEST volc_plot FUNCTION
options(repr.plot.width=6, repr.plot.height=4)
volc_plot(ASW_Ctrl_DeSQ_FC)
# Out:
# plot without title

# %%
# vignette("DESeq2")
